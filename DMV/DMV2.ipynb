# %%
pip install requests pandas matplotlib seaborn folium geopandas
# Out:
# Requirement already satisfied: requests in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (2.32.3)
# Requirement already satisfied: pandas in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: matplotlib in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (3.8.0)
# Requirement already satisfied: seaborn in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (0.13.2)
# Collecting folium
#   Downloading folium-0.18.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from requests) (2023.11.17)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from folium) (3.1.2)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.6.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.6-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.0 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: six>=1.5 in /Users/dhruvpai/miniconda3/envs/myenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading folium-0.18.0-py2.py3-none-any.whl (108 kB)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading branca-0.8.0-py3-none-any.whl (25 kB)
# Downloading pyogrio-0.10.0-cp39-cp39-macosx_12_0_arm64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 6.2 MB/s eta 0:00:00a 0:00:01
# Downloading pyproj-3.6.1-cp39-cp39-macosx_11_0_arm64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 13.4 MB/s eta 0:00:00a 0:00:01
# Downloading shapely-2.0.6-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.7 MB/s eta 0:00:00
# Downloading xyzservices-2024.9.0-py3-none-any.whl (85 kB)
# Installing collected packages: xyzservices, shapely, pyproj, pyogrio, branca, geopandas, folium
# Successfully installed branca-0.8.0 folium-0.18.0 geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.6.1 shapely-2.0.6 xyzservices-2024.9.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import folium  # For geospatial visualization
import numpy as np

# %%
# Step 1: Replace with your OpenWeatherMap API key
api_key = "9b2c72bec82d707513240e74767a8861"

# %%
# Step 2: Specify location for weather data retrieval
location = "San Francisco"
url = f"http://api.openweathermap.org/data/2.5/forecast?q={location}&appid={api_key}&units=metric"

# %%
# Step 3: Retrieve data from OpenWeatherMap API
response = requests.get(url)
weather_data = response.json()

# %%
print(weather_data)  # Check the actual API response to understand what went wrong
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1731304800, 'main': {'temp': 13.91, 'feels_like': 13.42, 'temp_min': 13.91, 'temp_max': 14, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 1015, 'humidity': 79, 'temp_kf': -0.09}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 47}, 'wind': {'speed': 2.38, 'deg': 173, 'gust': 3.67}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2024-11-11 06:00:00'}, {'dt': 1731315600, 'main': {'temp': 13.83, 'feels_like': 13.36, 'temp_min': 13.82, 'temp_max': 13.83, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 1014, 'humidity': 80, 'temp_kf': 0.01}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 67}, 'wind': {'speed': 2.59, 'deg': 164, 'gust': 4.54}, 'visibility': 10000, 'pop': 0.03, 'sys': {'pod': 'n'}, 'dt_txt': '2024-11-11 09:00:00'}, {'dt': 1731326400, 'main': {'temp': 13.92, 'feels_like': 13.53, 'temp_min': 13.92, 'temp_max': 13.92, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 1013, 'humidity': 83, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 86}, 'wind': {'speed': 3.4, 'deg': 172, 'gust': 6.87}, 'visibility': 10000, 'pop': 0.3, 'rain': {'3h': 0.19}, 'sys': {'pod': 'n'}, 'dt_txt': '2024-11-11 12:00:00'}, {'dt': 1731337200, 'main': {'temp': 14.34, 'feels_like': 14.1, 'temp_min': 14.34, 'temp_max': 14.34, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 1013, 'humidity': 87, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 100}, 'wind': {'speed': 5.5, 'deg': 176, 'gust': 9.99}, 'visibility': 10000, 'pop': 0.32, 'rain': {'3h': 0.23}, 'sys': {'pod': 'd'}, 'dt_txt': '2024-11-11 15:00:00'}, {'dt': 1731348000, 'main': {'temp': 12.42, 'feels_like': 11.86, 'temp_min': 12.42, 'temp_max': 12.42, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 1015, 'humidity': 82, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 98}, 'wind': {'speed': 9.68, 'deg': 293, 'gust': 15.03}, 'visibility': 10000, 'pop': 0.89, 'rain': {'3h': 2.89}, 'sys': {'pod': 'd'}, 'dt_txt': '2024-11-11 18:00:00'}, {'dt': 1731358800, 'main': {'temp': 12.11, 'feels_like': 11.49, 'temp_min': 12.11, 'temp_max': 12.11, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 1015, 'humidity': 81, 'temp_kf': 0}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'clouds': {'all': 100}, 'wind': {'speed': 4.05, 'deg': 258, 'gust': 5.03}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 4.08}, 'sys': {'pod': 'd'}, 'dt_txt': '2024-11-11 21:00:00'}, {'dt': 1731369600, 'main': {'temp': 12.62, 'feels_like': 11.82, 'temp_min': 12.62, 'temp_max': 12.62, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 1016, 'humidity': 72, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 58}, 'wind': {'speed': 5.64, 'deg': 278, 'gust': 8.03}, 'visibility': 10000, 'pop': 0.8, 'sys': {'pod': 'd'}, 'dt_txt': '2024-11-12 00:00:00'}, {'dt': 1731380400, 'main': {'temp': 11.81, 'feels_like': 11.24, 'temp_min': 11.81, 'temp_max': 11.81, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 1017, 'humidity': 84, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 4.97, 'deg': 285, 'gust': 8.67}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2024-11-12 03:00:00'}, {'dt': 1731391200, 'main': {'temp': 11.8, 'feels_like': 11.15, 'temp_min': 11.8, 'temp_max': 11.8, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1019, 'humidity': 81, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 1}, 'wind': {'speed': 4.6, 'deg': 300, 'gust':  ...

# %%
if 'list' in weather_data:
    weather_list = weather_data['list']
    extracted_data = []

    for entry in weather_list:
        extracted_data.append({
            "datetime": datetime.fromtimestamp(entry["dt"]),
            "temperature": entry["main"]["temp"],
            "humidity": entry["main"]["humidity"],
            "wind_speed": entry["wind"]["speed"],
            "precipitation": entry.get("rain", {}).get("3h", 0),  # 3-hour precipitation, default to 0 if not available
            "lat": weather_data["city"]["coord"]["lat"],
            "lon": weather_data["city"]["coord"]["lon"]
        })
else:
    print("Error in API response:", weather_data.get("message", "Unknown error"))

# %%
# Step 5: Create DataFrame and clean data
df = pd.DataFrame(extracted_data)

# %%
# Handle missing values by filling with mean (if any)
df.fillna(df.mean(), inplace=True)

# %%
# Step 6: Perform data modeling and basic analysis
# Calculating average temperature and humidity over the entire period
avg_temp = df['temperature'].mean()
avg_humidity = df['humidity'].mean()

# %%
# Calculating maximum and minimum values
max_temp = df['temperature'].max()
min_temp = df['temperature'].min()
max_wind_speed = df['wind_speed'].max()

# %%
print(f"Average Temperature: {avg_temp:.2f}°C")
print(f"Maximum Temperature: {max_temp}°C")
print(f"Minimum Temperature: {min_temp}°C")
print(f"Maximum Wind Speed: {max_wind_speed} m/s")
# Out:
# Average Temperature: 12.48°C
# Maximum Temperature: 14.5°C
# Minimum Temperature: 9.96°C
# Maximum Wind Speed: 9.68 m/s

# %%
# Step 7: Data Aggregation for daily summaries
df['date'] = df['datetime'].dt.date
daily_summary = df.groupby('date').agg({
    'temperature': ['mean', 'max', 'min'],
    'humidity': 'mean',
    'wind_speed': 'mean',
    'precipitation': 'sum'
}).reset_index()

# %%
# Step 8: Visualization

# Line Plot for Temperature over time
plt.figure(figsize=(10, 5))
plt.plot(df['datetime'], df['temperature'], color='blue', label='Temperature (°C)')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.title(f"Temperature Over Time in {location}")
plt.legend()
plt.show()

# %%
# Bar Plot for Daily Precipitation
plt.figure(figsize=(10, 5))
plt.bar(daily_summary['date'], daily_summary['precipitation']['sum'], color='skyblue')
plt.xlabel('Date')
plt.ylabel('Precipitation (mm)')
plt.title(f"Daily Precipitation in {location}")
plt.xticks(rotation=45)
plt.show()

# %%
# Step 9: Geospatial Visualization of Location
map = folium.Map(location=[df['lat'][0], df['lon'][0]], zoom_start=10)
folium.Marker([df['lat'][0], df['lon'][0]], popup=location).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3899d127570478da77f6155110e82365 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3899d127570478da77f6155110e82365&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3899d127570478da77f6155110e82365 = L.map(
#                 &quot;map_3899d127570478da77f6155110e82365&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cc286fca715d880acfb737443d41830 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6cc286fca715d880acfb737443d41830.addTo(map_3899d127570478da77f6155110e82365);
#
#
#             var marker_be6543bcf901247511c5d1406daa40b3 = L.marker(
#                 [37.7749, -122.4194],
#                 {}
#             ).addTo(map_3899d127570478da77f6155110e82365);
#
#
#         var popup_a44c2145d6cb185d81f4dd8dadc9f462 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b16d83294a212ccbe725498e772e5331 = $(`&lt;div id=&quot;html_b16d83294a212ccbe725498e772e5331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_a44c2145d6cb185d81f4dd8dadc9f462.setContent(html_b16d83294a212ccbe725498e772e5331);
#
#
#
#         marker_be6543bcf901247511c5d1406daa40b3.bindPopup(popup_a44c2145d6cb185d81f4dd8dadc9f462)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Step 10: Correlation Plot between weather attributes
plt.figure(figsize=(8, 6))
sns.heatmap(df[['temperature', 'humidity', 'wind_speed', 'precipitation']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between Weather Attributes")
plt.show()

# %% [markdown]
# Explanation of Each Task
#
# API Key Registration: You need to replace YOUR_API_KEY with your actual OpenWeatherMap API key.
#
# Data Retrieval: A forecast endpoint is used here, which returns 3-hour interval data for up to 5 days.
#
# Data Extraction: We extract temperature, humidity, wind speed, and precipitation data along with coordinates.
#
# Data Cleaning: Missing values are handled by filling them with the mean of the column.
#
# Data Modeling: Basic calculations, including average, maximum, and minimum values, give insights into the weather patterns.
#
# Visualization:
# Line Chart for temperature over time.
# Bar Chart for daily precipitation totals.
#
# Data Aggregation: Daily statistics are calculated for average temperature, humidity, and total precipitation.
#
# Geospatial Visualization: Displays the location of the city on a map using folium.
#
# Correlation Analysis: Correlation heatmap shows relationships between temperature, humidity, wind speed, and precipitation.
